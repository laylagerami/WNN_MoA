# %% [markdown]
# ## Prepare data for analysis

# %%
import pandas as pd
from glob import glob
from scipy.stats import spearmanr, pearsonr
import numpy as np
import itertools
from fuzzywuzzy import fuzz # req. python-Levenshtein

# %% [markdown]
# ### L1000

# %%
glob("../LINCS-Pilot1/L1000/*")
# Out:
# ['../LINCS-Pilot1/L1000/level_5_rank.csv',
#  '../LINCS-Pilot1/L1000/level_4.csv',
#  '../LINCS-Pilot1/L1000/collapsed_replicates.csv',
#  '../LINCS-Pilot1/L1000/replicate_level_l1k.csv',
#  '../LINCS-Pilot1/L1000/level_4W.csv',
#  '../LINCS-Pilot1/L1000/level_3.csv',
#  '../LINCS-Pilot1/L1000/level_5_modz.csv']

# %%
level_4 = pd.read_csv('../LINCS-Pilot1/L1000/replicate_level_l1k.csv')
level_4
# Out:
#                                 cid  200814_at  222103_at  201453_x_at  \
# 0      REP.A001_A549_24H_X1_B27:A03     0.3547    -0.4940      -0.1721
# 1      REP.A001_A549_24H_X1_B27:A04    -0.2130     0.4931      -0.8768
# 2      REP.A001_A549_24H_X1_B27:A05    -0.3280    -0.4555       0.3819
# 3      REP.A001_A549_24H_X1_B27:A06     0.1175    -0.9678      -0.3185
# 4      REP.A001_A549_24H_X1_B27:A07     0.5254     0.0000      -0.4691
# ...                             ...        ...        ...          ...
# 27832  REP.A028_A549_24H_X3_B29:P20    -1.4560    -1.0966       0.8633
# 27833  REP.A028_A549_24H_X3_B29:P21     0.5672     0.2946      -1.9837
# 27834  REP.A028_A549_24H_X3_B29:P22    -0.9993    -0.6982       0.1973
# 27835  REP.A028_A549_24H_X3_B29:P23     0.3532    -0.7262      -0.1420
# 27836  REP.A028_A549_24H_X3_B29:P24    -1.0144    -1.0432      -1.1501
#
#        204131_s_at  200059_s_at  205067_at  213702_x_at  214435_x_at  \
# 0          -0.0339      -0.4355     1.8263      -0.1316       0.0853
# 1          -0.6968      -1.7018    -0.3779      -0.6745      -1.9799
# 2          -1.1447       0.0951    -0.5498      -0.6745      -0.0950
# 3           0.4623      -0.2842    -0.9202      -0.8413       0.7160
# 4           0.3652      -1.0688     0.0793      -1.1123       0.1908
# ...            ...          ...        ...          ...          ...
# 27832      -0.4426       2.3494    -0.0464       0.3133       0.0838
# 27833      -0.6680       0.5777     0.0080      -0.8276       0.5831
# 27834      -0.6394       0.1946    -0.2364      -0.4217      -0.4877
# 27835       0.6304       1.0234     0.1308      -0.4872       0.7299
# 27836      -0.9659       0.0658    -0.2523       0.3206      -0.7915
#
#        201334_s_at  ...  nearest_dose        brew_prefix  \
# 0          -0.4660  ...       -666.00  REP.A001_A549_24H
# 1          -1.1429  ...       -666.00  REP.A001_A549_24H
# 2          -0.2946  ...       -666.00  REP.A001_A549_24H
# 3           0.3384  ...       -666.00  REP.A001_A549_24H
# 4          -0.8249  ...         10.00  REP.A001_A549_24H
# ...            ...  ...           ...                ...
# 27832      -0.3306  ...          3.33  REP.A028_A549_24H
# 27833       0.5613  ...          1.11  REP.A028_A549_24H
# 27834      -1.8497  ...          0.37  REP.A028_A549_24H
# 27835       0.4346  ...          0.12  REP.A028_A549_24H
# 27836       0.8230  ...          0.04  REP.A028_A549_24H
#
#                     group_id  nsig  cc_q75   tas_q75    pert_iname_y  \
# 0      REP.A001_A549_24H:A03   500  0.1800  0.165592            DMSO
# 1      REP.A001_A549_24H:A04   500  0.1800  0.165592            DMSO
# 2      REP.A001_A549_24H:A05   500  0.1800  0.165592            DMSO
# 3      REP.A001_A549_24H:A06   500  0.1800  0.165592            DMSO
# 4      REP.A001_A549_24H:A07     6  0.0850  0.086878  aminoguanidine
# ...                      ...   ...     ...       ...             ...
# 27832  REP.A028_A549_24H:P20     6  0.1275  0.127916  cyanocobalamin
# 27833  REP.A028_A549_24H:P21     6  0.1275  0.127916  cyanocobalamin
# 27834  REP.A028_A549_24H:P22     6  0.1275  0.127916  cyanocobalamin
# 27835  REP.A028_A549_24H:P23     6  0.1275  0.127916  cyanocobalamin
# 27836  REP.A028_A549_24H:P24     6  0.1275  0.127916  cyanocobalamin
#
#        pert_type_y                                           moa  \
# 0      ctl_vehicle                               Control vehicle
# 1      ctl_vehicle                               Control vehicle
# 2      ctl_vehicle                               Control vehicle
# 3      ctl_vehicle                               Control vehicle
# 4           trt_cp               Nitric oxide synthase inhibitor
# ...            ...                                           ...
# 27832       trt_cp  Methylmalonyl CoA mutase stimulant|Vitamin B
# 27833       trt_cp  Methylmalonyl CoA mutase stimulant|Vitamin B
# 27834       trt_cp  Methylmalonyl CoA mutase stimulant|Vitamin B
# 27835       trt_cp  Methylmalonyl CoA mutase stimulant|Vitamin B
# 27836       trt_cp  Methylmalonyl CoA mutase stimulant|Vitamin B
#
#              pert_id_dose
# 0                    DMSO
# 1                    DMSO
# 2                    DMSO
# 3                    DMSO
# 4        BRD-K25114078_10
# ...                   ...
# 27832  BRD-A97502381_3.33
# 27833  BRD-A97502381_1.11
# 27834  BRD-A97502381_0.37
# 27835  BRD-A97502381_0.12
# 27836  BRD-A97502381_0.04
#
# [27837 rows x 1030 columns]

# %%
# define columns with data, and columns with metadata
gex_cols =  [col for col in level_4.columns if '_at' in col] # get cols for gex data
other_cols = [col for col in level_4.columns if '_at' not in col] # get metadata cols

# %%
# Collapse replicates
progress = progressbar.ProgressBar() # pbar
group_ids = list(set(level_4['pert_id_dose'].tolist())) # get group ids for subsetting

df_list = [] # init list of rows
for groupid in progress(group_ids):
    # subset replicates
    subset = level_4[level_4['pert_id_dose']==groupid]
    
    if len(subset) == 1: # if only one replicate just keep it
        consensus_sig = subset[gex_cols]
        other_data = subset[other_cols]
        other_data_df = pd.DataFrame(other_data.iloc[0,:]).T
        other_data_df.reset_index(inplace=True)
        consensus_sig[other_data_df.columns]=other_data_df

    if len(subset) ==2: # get median if 2 replicates
        gex_data = subset[gex_cols]
        consensus_sig = pd.DataFrame(gex_data.median()).T 
        other_data = subset[other_cols]
        other_data_df = pd.DataFrame(other_data.iloc[0,:]).T
        other_data_df.reset_index(inplace=True)
        consensus_sig[other_data_df.columns]=other_data_df
     
    if len(subset) > 2:
        # extract gex data
        gex_data = subset[gex_cols]
        gex_data_t = gex_data.T

        # get correlation matrix
        corr_reps = pd.DataFrame(gex_data_t.corr(method='spearman'))
        a = np.array(corr_reps)
        np.fill_diagonal(a,'NaN')
        corr_reps_nan = pd.DataFrame(a)

        # turn correlation into weights
        col_weights = []
        for col in corr_reps_nan:
            col_weight = corr_reps_nan[col].sum()
            col_weights.append(col_weight)
        try:
            col_weights_norm = [float(i)/sum(col_weights) for i in col_weights]
        except RuntimeWarning:
            break

        # linear combination of weighted signatures
        linear_list = []
        for idx, weight in enumerate(col_weights_norm):
            linear = gex_data_t.iloc[:,idx]*col_weights_norm[idx]
            linear_list.append(linear)
        combined_sig = sum(linear_list)
        combined_sig = list(map(str, combined_sig))
        consensus_sig = pd.DataFrame(combined_sig).T
        consensus_sig.columns = gex_data.columns

        # merge with other cols
        other_data = subset[other_cols]
        other_data_df = pd.DataFrame(other_data.iloc[0,:]).T
        other_data_df.reset_index(inplace=True)
        consensus_sig[other_data_df.columns]=other_data_df

    # apppend
    df_list.append(consensus_sig)

# %%
# concat rows to get final df of collapsed replicates
collapsed_replicates = pd.concat(df_list)

collapsed_replicates.to_csv("../LINCS-Pilot1/L1000/collapsed_replicates.csv",index=False)

# %%
collapsed_replicates_l1000 = pd.read_csv("../LINCS-Pilot1/L1000/collapsed_replicates.csv")
collapsed_replicates_l1000
# Out:
#       200814_at  222103_at  201453_x_at  204131_s_at  200059_s_at  205067_at  \
# 0      0.127162  -0.294365     0.137961    -1.109703     0.656604   0.292215
# 1      1.118993   0.227189    -0.331341     0.945928     1.006607  -0.650126
# 2      0.245591   0.282655     0.218872     0.684023     0.714155  -0.664439
# 3     -0.335456   0.586743    -0.591421     0.264353     0.540535  -1.283997
# 4      0.080376   0.158033    -0.015609     0.048414     0.541595   0.090768
# ...         ...        ...          ...          ...          ...        ...
# 8365  -0.025300  -0.622900    -0.100200    -0.095050     0.631850  -0.189400
# 8366  -0.613532   0.487759    -0.340595    -1.060928    -0.477456   1.896124
# 8367  -3.688331  -1.325052    -4.263548    -0.278700    -0.476889   3.471311
# 8368   0.419450  -0.291217     0.388290    -1.011088    -0.436046  -0.783107
# 8369  -2.055755  -1.000244    -0.377710    -1.273223    -3.743680   3.103140
#
#       213702_x_at  214435_x_at  201334_s_at  213721_at  ...  nearest_dose  \
# 0        0.311967     0.447751     0.037203  -0.340880  ...          0.37
# 1        0.684648    -0.326644     0.527731  -0.207947  ...          1.11
# 2       -0.010907    -0.899365     0.231252  -0.909358  ...          3.33
# 3        0.211161     0.778915     1.353914  -0.230887  ...          0.37
# 4        0.163494     0.014289     0.136539  -0.274216  ...          0.12
# ...           ...          ...          ...        ...  ...           ...
# 8365    -1.136650     0.164750     0.486000   1.446050  ...          0.37
# 8366     0.069570     0.890457    -0.556072   1.651810  ...          3.33
# 8367    -6.102801     7.646394     0.513694   1.647447  ...          0.37
# 8368     0.523110     0.540916     0.025963  -0.513424  ...          0.37
# 8369    -0.470018     0.189007    -3.042808  -5.095214  ...          1.11
#
#             brew_prefix               group_id  nsig  cc_q75   tas_q75  \
# 0     REP.A003_A549_24H  REP.A003_A549_24H:C10   6.0  0.1150  0.123915
# 1     REP.A027_A549_24H  REP.A027_A549_24H:B09   6.0  0.2100  0.185869
# 2     REP.A022_A549_24H  REP.A022_A549_24H:O14   6.0  0.2175  0.188351
# 3     REP.A011_A549_24H  REP.A011_A549_24H:M16   6.0  0.2175  0.177029
# 4     REP.A016_A549_24H  REP.A016_A549_24H:D05   6.0  0.1950  0.144414
# ...                 ...                    ...   ...     ...       ...
# 8365  REP.A024_A549_24H  REP.A024_A549_24H:O16   6.0  0.0775  0.092266
# 8366  REP.A004_A549_24H  REP.A004_A549_24H:A20   6.0  0.2150  0.188559
# 8367  REP.A023_A549_24H  REP.A023_A549_24H:F22   6.0  0.1075  0.088196
# 8368  REP.A026_A549_24H  REP.A026_A549_24H:B16   6.0  0.2700  0.213961
# 8369  REP.A016_A549_24H  REP.A016_A549_24H:D03   6.0  0.1950  0.144414
#
#       pert_iname_y  pert_type_y  \
# 0       pemirolast       trt_cp
# 1       oglemilast       trt_cp
# 2       elesclomol       trt_cp
# 3          esmolol       trt_cp
# 4        ilomastat       trt_cp
# ...            ...          ...
# 8365      bavisant       trt_cp
# 8366  trimipramine       trt_cp
# 8367     diacerein       trt_cp
# 8368        CYT387       trt_cp
# 8369     ilomastat       trt_cp
#
#                                                     moa        pert_id_dose
# 0                            Mediator release inhibitor  BRD-K31731454_0.37
# 1                           Phosphodiesterase inhibitor  BRD-K92303087_1.11
# 2                              Oxidative stress inducer  BRD-K82135108_3.33
# 3                        Adrenergic receptor antagonist  BRD-A07395371_0.37
# 4                      Matrix metalloprotease inhibitor  BRD-K51662849_0.12
# ...                                                 ...                 ...
# 8365                      Histamine receptor antagonist  BRD-K79595931_0.37
# 8366  Norepinephrine reputake inhibitor|Tricyclic an...  BRD-A19195498_3.33
# 8367                              Interleukin inhibitor  BRD-K69122748_0.37
# 8368                                                NaN  BRD-K87737963_0.37
# 8369                   Matrix metalloprotease inhibitor  BRD-K51662849_1.11
#
# [8370 rows x 1031 columns]

# %% [markdown]
# ### Cell Morphology

# %%
cell_painting = pd.read_csv('../LINCS-Pilot1/CellPainting/replicate_level_cp_normalized.csv.gz')
cell_painting.head()
# Out:
# /scratch/lh605/envs/janssen/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (18,19,1820,1821) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   Metadata_plate_map_name Metadata_broad_sample  Metadata_mg_per_ml  \
# 0       C-7161-01-LM6-018                  DMSO                 0.0
# 1       C-7161-01-LM6-018                  DMSO                 0.0
# 2       C-7161-01-LM6-018                  DMSO                 0.0
# 3       C-7161-01-LM6-018                  DMSO                 0.0
# 4       C-7161-01-LM6-018                  DMSO                 0.0
#
#    Metadata_mmoles_per_liter Metadata_solvent Metadata_pert_id  \
# 0                        0.0             DMSO              NaN
# 1                        0.0             DMSO              NaN
# 2                        0.0             DMSO              NaN
# 3                        0.0             DMSO              NaN
# 4                        0.0             DMSO              NaN
#
#   Metadata_pert_mfc_id Metadata_pert_well  Metadata_pert_id_vendor  \
# 0                  NaN                A01                      NaN
# 1                  NaN                A02                      NaN
# 2                  NaN                A03                      NaN
# 3                  NaN                A04                      NaN
# 4                  NaN                A05                      NaN
#
#   Metadata_cell_id  ... pert_iname InChIKey14  moa target broad_date  \
# 0             A549  ...        NaN        NaN  NaN    NaN        NaN
# 1             A549  ...        NaN        NaN  NaN    NaN        NaN
# 2             A549  ...        NaN        NaN  NaN    NaN        NaN
# 3             A549  ...        NaN        NaN  NaN    NaN        NaN
# 4             A549  ...        NaN        NaN  NaN    NaN        NaN
#
#   clinical_phase alternative_moa alternative_target Metadata_dose_recode  \
# 0            NaN             NaN                NaN                 0.04
# 1            NaN             NaN                NaN                 0.04
# 2            NaN             NaN                NaN                 0.04
# 3            NaN             NaN                NaN                 0.04
# 4            NaN             NaN                NaN                 0.04
#
#   Metadata_pert_id_dose
# 0                  DMSO
# 1                  DMSO
# 2                  DMSO
# 3                  DMSO
# 4                  DMSO
#
# [5 rows x 1824 columns]

# %%
# Collapse replicates
progress = progressbar.ProgressBar() # pbar
feature_cols = [col for col in cell_painting.columns if 'Metadata' not in col][:-13] # get cols for cp data
other_cols = list(set(cell_painting.columns) - set(feature_cols)) # get metadata cols
group_ids = list(set(cell_painting['Metadata_pert_id_dose'].tolist())) # get group ids for subsetting

df_list = [] # init list of rows
for groupid in progress(group_ids):
    # subset replicates
    subset = cell_painting[cell_painting['Metadata_pert_id_dose']==groupid]
    
    if len(subset) == 1: # if only one replicate just keep it
        consensus_sig = subset[feature_cols]
        other_data = subset[other_cols]
        other_data_df = pd.DataFrame(other_data.iloc[0,:]).T
        other_data_df.reset_index(inplace=True)
        consensus_sig[other_data_df.columns]=other_data_df

    if len(subset) ==2: # get median if 2 replicates
        cp_data = subset[feature_cols]
        consensus_sig = pd.DataFrame(cp_data.median()).T 
        other_data = subset[other_cols]
        other_data_df = pd.DataFrame(other_data.iloc[0,:]).T
        other_data_df.reset_index(inplace=True)
        consensus_sig[other_data_df.columns]=other_data_df
     
    if len(subset) > 2:
        # extract cp data
        cp_data = subset[feature_cols]
        cp_data_t = cp_data.T

        # get correlation matrix
        corr_reps = pd.DataFrame(cp_data_t.corr(method='spearman'))
        a = np.array(corr_reps)
        np.fill_diagonal(a,'NaN')
        corr_reps_nan = pd.DataFrame(a)

        # turn correlation into weights
        col_weights = []
        for col in corr_reps_nan:
            col_weight = corr_reps_nan[col].sum()
            col_weights.append(col_weight)
        try:
            col_weights_norm = [float(i)/sum(col_weights) for i in col_weights]
        except RuntimeWarning:
            break

        # linear combination of weighted signatures
        linear_list = []
        for idx, weight in enumerate(col_weights_norm):
            linear = cp_data_t.iloc[:,idx]*col_weights_norm[idx]
            linear_list.append(linear)
        combined_sig = sum(linear_list)
        combined_sig = list(map(str, combined_sig))
        consensus_sig = pd.DataFrame(combined_sig).T
        consensus_sig.columns = cp_data.columns

        # merge with other cols
        other_data = subset[other_cols]
        other_data_df = pd.DataFrame(other_data.iloc[0,:]).T
        other_data_df.reset_index(inplace=True)
        consensus_sig[other_data_df.columns]=other_data_df

    # apppend
    df_list.append(consensus_sig)

# %%
# concat rows to get final df of collapsed replicates
collapsed_replicates = pd.concat(df_list)

# %%
collapsed_replicates.to_csv("../LINCS-Pilot1/CellPainting/collapsed_replicates.csv",index=False)

# %%
collapsed_replicates_image = pd.read_csv("../LINCS-Pilot1/CellPainting/collapsed_replicates.csv")
collapsed_replicates_image
# Out:
# /scratch/lh605/envs/janssen/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (1794,1818) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       Cells_AreaShape_Area  Cells_AreaShape_Center_X  \
# 0                 0.930886                 -0.005492
# 1                -0.885841                 -0.361874
# 2                 4.563952                  0.024727
# 3                 0.689370                  0.361192
# 4                 0.891200                  0.362412
# ...                    ...                       ...
# 9390             -1.264650                  0.242205
# 9391             -0.257541                  0.149125
# 9392              3.695259                  1.150862
# 9393              1.624630                  1.208450
# 9394              0.534182                  0.287830
#
#       Cells_AreaShape_Center_Y  Cells_AreaShape_Compactness  \
# 0                     0.469358                     2.018657
# 1                    -0.011127                     8.049175
# 2                    -0.004964                     0.496530
# 3                     0.230801                    -0.151581
# 4                     0.558520                     0.341306
# ...                        ...                          ...
# 9390                 -0.216349                     0.073602
# 9391                  0.269169                    -0.335828
# 9392                  0.591856                     0.127483
# 9393                  0.115900                    -0.843845
# 9394                 -1.048757                    -0.103024
#
#       Cells_AreaShape_Eccentricity  Cells_AreaShape_EulerNumber  \
# 0                         1.426170                          0.0
# 1                         4.271658                          0.0
# 2                         0.066990                          0.0
# 3                         0.641382                          0.0
# 4                         0.597724                          0.0
# ...                            ...                          ...
# 9390                      0.977056                          0.0
# 9391                     -0.238082                          0.0
# 9392                      0.819892                          0.0
# 9393                     -0.921275                          0.0
# 9394                     -0.069859                          0.0
#
#       Cells_AreaShape_Extent  Cells_AreaShape_FormFactor  \
# 0                  -1.348686                    0.043441
# 1                  -6.700333                   -0.471099
# 2                  -2.239999                   -8.065502
# 3                   0.301334                   -3.074680
# 4                  -0.846607                   -0.214280
# ...                      ...                         ...
# 9390                0.077212                   -1.266096
# 9391                0.676743                    1.988955
# 9392                0.469361                   -5.235946
# 9393               -1.336675                   -4.687450
# 9394                0.270588                    0.173385
#
#       Cells_AreaShape_MajorAxisLength  Cells_AreaShape_MaxFeretDiameter  ...  \
# 0                            0.975899                          0.929508  ...
# 1                            0.389882                          0.568959  ...
# 2                            4.028972                          4.260322  ...
# 3                            0.628350                          0.743517  ...
# 4                            1.211368                          1.318890  ...
# ...                               ...                               ...  ...
# 9390                        -1.168330                         -1.200381  ...
# 9391                        -0.370205                         -0.341625  ...
# 9392                         4.264099                          4.360206  ...
# 9393                         2.547390                          2.075770  ...
# 9394                         0.578110                          0.537962  ...
#
#            broad_id   Metadata_broad_sample  Metadata_alternative_moa  \
# 0     BRD-K93123848  BRD-K93123848-001-04-1                       NaN
# 1     BRD-K72215350  BRD-K72215350-001-06-5                       NaN
# 2     BRD-A62025033  BRD-A62025033-001-01-8                       NaN
# 3     BRD-K31627533  BRD-K31627533-001-09-5                       NaN
# 4     BRD-K04956647  BRD-K04956647-003-02-5                       NaN
# ...             ...                     ...                       ...
# 9390  BRD-K55966568  BRD-K55966568-001-05-4                       NaN
# 9391  BRD-K82225283  BRD-K82225283-001-03-1                       NaN
# 9392  BRD-K41708980  BRD-K41708980-001-01-6                       NaN
# 9393  BRD-K44353683  BRD-K44353683-001-08-3                       NaN
# 9394  BRD-K02992638  BRD-K02992638-001-11-8                       NaN
#
#       alternative_target  Metadata_dose_recode  Metadata_InChIKey14  \
# 0                    NaN                  0.12       YABJJWZLRMPFSI
# 1                    NaN                 10.00       WDSCBUNMANHPFH
# 2                    NaN                  1.11                  NaN
# 3                    NaN                  0.12       QTTRZHGPGKRAFB
# 4                    NaN                  3.33       KOHIRBRYDXPAMZ
# ...                  ...                   ...                  ...
# 9390                 NaN                  1.11       NHFDRBXTEDBWCZ
# 9391                 NaN                  3.33       YWXYYJSYQOXTPL
# 9392                 NaN                  3.33       YNDXUCZADRHECN
# 9393                 NaN                  3.33       OELFLUMRDSZNSF
# 9394                 NaN                  0.12       JTEGQNOMFQHVDC
#
#       Metadata_pert_id_vendor  Metadata_broad_sample_type  \
# 0                         NaN                         trt
# 1                         NaN                         trt
# 2                         NaN                         trt
# 3                         NaN                         trt
# 4                         NaN                         trt
# ...                       ...                         ...
# 9390                      NaN                         trt
# 9391                      NaN                         trt
# 9392                      NaN                         trt
# 9393                      NaN                         trt
# 9394                      NaN                         trt
#
#       Metadata_mmoles_per_liter  Batch_Date
# 0                       0.12346  2016-03-22
# 1                      10.00000  2016-03-22
# 2                       1.11110  2016-03-22
# 3                       0.12346  2016-03-22
# 4                       3.33330  2016-03-22
# ...                         ...         ...
# 9390                    1.11110  2016-03-22
# 9391                    3.33330  2016-03-22
# 9392                    3.33330  2016-03-22
# 9393                    3.33330  2016-03-22
# 9394                    0.12346  2016-03-22
#
# [9395 rows x 1825 columns]

# %% [markdown]
# ### Compound structural data

# %% [markdown]
# First, find intersection of image + l1000 data and create a lookup file

# %%
l1000_comps = list(set(collapsed_replicates_l1000['pert_id'].tolist()))
len(l1000_comps) # 1403 L1000 compounds (plus nan)
# Out:
# 1404

# %%
image_comps = list(set(collapsed_replicates_image['Metadata_pert_id'].tolist()))
len(image_comps) # l570 image compounds (plus nan)
# Out:
# 1571

# %%
both_data = list(set(l1000_comps)&set(image_comps))
len(both_data) # 1402 in both (plus nan)
# Out:
# 1403

# %%
compoundinfo_beta = pd.read_csv("compoundinfo_beta.txt",sep="\t")
compoundinfo_beta
compoundinfo_filtered = compoundinfo_beta[compoundinfo_beta['pert_id'].isin(both_data)]
compoundinfo_filtered_perts = list(set(compoundinfo_filtered['pert_id'].tolist()))
len(compoundinfo_filtered_perts) # we have all of the compound data here!
# Out:
# 1402

# %%
compound_metadata = compoundinfo_filtered.iloc[:,[0,1,3,4,5]]
compound_metadata
# Out:
#              pert_id          cmap_name  \
# 1      BRD-A12237696       L-citrulline
# 8      BRD-K05674516           PSI-7976
# 15     BRD-K26341917    L-ergothioneine
# 18     BRD-K29133151      BRD-K29133151
# 19     BRD-K29968218            KX-2391
# ...              ...                ...
# 39305  BRD-A66155091         trilostane
# 39306  BRD-A66155091         trilostane
# 39307  BRD-A66155091         trilostane
# 39315  BRD-K99504665  goserelin-acetate
# 39316  BRD-K62685538        triptorelin
#
#                                                      moa  \
# 1                                                    NaN
# 8                                                    NaN
# 15                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# ...                                                  ...
# 39305  3beta-hydroxy-delta5-steroid dehydrogenase inh...
# 39306  3beta-hydroxy-delta5-steroid dehydrogenase inh...
# 39307  3beta-hydroxy-delta5-steroid dehydrogenase inh...
# 39315  Gonadotropin releasing factor hormone receptor...
# 39316  Gonadotropin releasing factor hormone receptor...
#
#                                         canonical_smiles  \
# 1                                   NC(CCCNC(N)=O)C(O)=O
# 8      CC(C)OC(=O)[C@H](C)N[P@@](=O)(OC[C@H]1O[C@@H](...
# 15           C[N+](C)(C)[C@@H](Cc1c[nH]c(=S)[nH]1)C(O)=O
# 18     OC(=O)CCCC=C/C[C@@H]1CO[C@@H](O[C@@H]1c1ccccc1...
# 19      O=C(Cc1ccc(cn1)-c1ccc(OCCN2CCOCC2)cc1)NCc1ccccc1
# ...                                                  ...
# 39305  C[C@]12CC[C@@H]3[C@@H](CC[C@@]45O[C@@H]4C(=O)C...
# 39306  C[C@]12CC[C@@H]3[C@@H](CC[C@@]45O[C@@H]4C(=O)C...
# 39307  C[C@]12CC[C@@H]3[C@@H](CC[C@@]45O[C@@H]4C(=O)C...
# 39315  CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...
# 39316  CC(C)C[C@H](NC(=O)[C@@H](Cc1c[nH]c2ccccc12)NC(...
#
#                          inchi_key
# 1      RHGKLRLOHDJJDR-UHFFFAOYSA-N
# 8      TTZHDVOVKQGIBA-YBSJRAAASA-N
# 15     SSISHJJTAXXQAX-ZETCQYMHSA-O
# 18     ZWAVGFSZMACJHA-PMNBYGLBSA-N
# 19     HUNGUWOZPQBXGX-UHFFFAOYSA-N
# ...                            ...
# 39305  RLQVKDVIBJCQGE-VWWPZJNLSA-N
# 39306  RLQVKDVIBJCQGE-VWWPZJNLSA-N
# 39307  RLQVKDVIBJCQGE-VWWPZJNLSA-N
# 39315  BLCLNMBMMGCOAS-URPVMXJPSA-N
# 39316  VXKHXGOKWPXYNA-PGBVPBMZSA-N
#
# [3478 rows x 5 columns]

# %% [markdown]
# Fill in gaps for MoA from data files

# %%
image_moa = collapsed_replicates_image[collapsed_replicates_image['Metadata_pert_id'].isin(both_data)].loc[:,["Metadata_pert_id","moa"]]
image_moa.drop_duplicates(inplace=True)
image_moa.drop(image_moa.tail(1).index,inplace=True)
image_moa
# Out:
#      Metadata_pert_id                                                moa
# 0       BRD-K93123848                      RAF inhibitor|VEGFR inhibitor
# 1       BRD-K72215350                        5 alpha reductase inhibitor
# 2       BRD-A62025033                                                NaN
# 3       BRD-K31627533                    glucocorticoid receptor agonist
# 4       BRD-K04956647                     adrenergic receptor antagonist
# ...               ...                                                ...
# 5895    BRD-K88429204                  dihydrofolate reductase inhibitor
# 6205    BRD-K84683831  bacterial 30S ribosomal subunit inhibitor|bact...
# 6348    BRD-K95773607                  acetylcholine receptor antagonist
# 6421    BRD-K93460210  serotonin receptor antagonist|sodium channel b...
# 6577    BRD-K92041145     O6-alkylguanine-DNA alkyltransferase inhibitor
#
# [1402 rows x 2 columns]

# %%
l1000_moa = collapsed_replicates_l1000[collapsed_replicates_l1000['pert_id'].isin(both_data)].loc[:,["pert_id","moa"]]
l1000_moa.drop_duplicates(inplace=True)
l1000_moa
# Out:
#             pert_id                                                moa
# 0     BRD-K31731454                         Mediator release inhibitor
# 1     BRD-K92303087                        Phosphodiesterase inhibitor
# 2     BRD-K82135108                           Oxidative stress inducer
# 3     BRD-A07395371                     Adrenergic receptor antagonist
# 4     BRD-K51662849                   Matrix metalloprotease inhibitor
# ...             ...                                                ...
# 5273  BRD-A48237631  DNA alkylating drug|DNA inhibitor|DNA alkylati...
# 5370  BRD-K43887077                          Dopamine receptor agonist
# 5392  BRD-K13819402  Acetylcholinesterase inhibitor|Monoamine oxida...
# 5807  BRD-K91544578                                    Immunostimulant
# 6224  BRD-A07704283                       Dopamine receptor antagonist
#
# [1403 rows x 2 columns]

# %%
moa_both = pd.merge(l1000_moa,image_moa,left_on="pert_id",right_on="Metadata_pert_id",suffixes=("_l1000","_image")).drop(['Metadata_pert_id'],axis=1)
moa_both
# Out:
#             pert_id                                          moa_l1000  \
# 0     BRD-K31731454                         Mediator release inhibitor
# 1     BRD-K92303087                        Phosphodiesterase inhibitor
# 2     BRD-K82135108                           Oxidative stress inducer
# 3     BRD-A07395371                     Adrenergic receptor antagonist
# 4     BRD-K51662849                   Matrix metalloprotease inhibitor
# ...             ...                                                ...
# 1397  BRD-A48237631  DNA alkylating drug|DNA inhibitor|DNA alkylati...
# 1398  BRD-K43887077                          Dopamine receptor agonist
# 1399  BRD-K13819402  Acetylcholinesterase inhibitor|Monoamine oxida...
# 1400  BRD-K91544578                                    Immunostimulant
# 1401  BRD-A07704283                       Dopamine receptor antagonist
#
#                                               moa_image
# 0                            mediator release inhibitor
# 1                           phosphodiesterase inhibitor
# 2                              oxidative stress inducer
# 3                        adrenergic receptor antagonist
# 4                      matrix metalloprotease inhibitor
# ...                                                 ...
# 1397       DNA alkylating agent|DNA synthesis inhibitor
# 1398                          dopamine receptor agonist
# 1399  acetylcholinesterase inhibitor|monoamine oxida...
# 1400                                    immunostimulant
# 1401                       dopamine receptor antagonist
#
# [1402 rows x 3 columns]

# %%
all_metadata = pd.merge(compound_metadata,moa_both,on="pert_id")
all_metadata = all_metadata.drop_duplicates(subset=["pert_id"])
all_metadata
# Out:
#             pert_id          cmap_name  \
# 0     BRD-A12237696       L-citrulline
# 1     BRD-K05674516           PSI-7976
# 2     BRD-K26341917    L-ergothioneine
# 3     BRD-K29133151      BRD-K29133151
# 4     BRD-K29968218            KX-2391
# ...             ...                ...
# 3471  BRD-K21295289          senicapoc
# 3472  BRD-K92213669         lomitapide
# 3473  BRD-A66155091         trilostane
# 3476  BRD-K99504665  goserelin-acetate
# 3477  BRD-K62685538        triptorelin
#
#                                                     moa  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3471  Intermediate conductance potassium channel blo...
# 3472  Microsomal trigylceride transfer protein inhib...
# 3473  3beta-hydroxy-delta5-steroid dehydrogenase inh...
# 3476  Gonadotropin releasing factor hormone receptor...
# 3477  Gonadotropin releasing factor hormone receptor...
#
#                                        canonical_smiles  \
# 0                                  NC(CCCNC(N)=O)C(O)=O
# 1     CC(C)OC(=O)[C@H](C)N[P@@](=O)(OC[C@H]1O[C@@H](...
# 2           C[N+](C)(C)[C@@H](Cc1c[nH]c(=S)[nH]1)C(O)=O
# 3     OC(=O)CCCC=C/C[C@@H]1CO[C@@H](O[C@@H]1c1ccccc1...
# 4      O=C(Cc1ccc(cn1)-c1ccc(OCCN2CCOCC2)cc1)NCc1ccccc1
# ...                                                 ...
# 3471          NC(=O)C(c1ccccc1)(c1ccc(F)cc1)c1ccc(F)cc1
# 3472  FC(F)(F)CNC(=O)C1(CCCCN2CCC(CC2)NC(=O)c2ccccc2...
# 3473  C[C@]12CC[C@@H]3[C@@H](CC[C@@]45O[C@@H]4C(=O)C...
# 3476  CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...
# 3477  CC(C)C[C@H](NC(=O)[C@@H](Cc1c[nH]c2ccccc12)NC(...
#
#                         inchi_key  \
# 0     RHGKLRLOHDJJDR-UHFFFAOYSA-N
# 1     TTZHDVOVKQGIBA-YBSJRAAASA-N
# 2     SSISHJJTAXXQAX-ZETCQYMHSA-O
# 3     ZWAVGFSZMACJHA-PMNBYGLBSA-N
# 4     HUNGUWOZPQBXGX-UHFFFAOYSA-N
# ...                           ...
# 3471  SCTZUZTYRMOMKT-UHFFFAOYSA-N
# 3472  MBBCVAKAJPKAKM-UHFFFAOYSA-N
# 3473  RLQVKDVIBJCQGE-VWWPZJNLSA-N
# 3476  BLCLNMBMMGCOAS-URPVMXJPSA-N
# 3477  VXKHXGOKWPXYNA-PGBVPBMZSA-N
#
#                                               moa_l1000  \
# 0                                                   NaN
# 1                              RNA polymerase inhibitor
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3471  Intermediate conductance potassium channel blo...
# 3472  Microsomal trigylceride transfer protein inhib...
# 3473  3beta-hydroxy-delta5-steroid dehydrogenase inh...
# 3476  Gonadotropin releasing factor hormone receptor...
# 3477  Gonadotropin releasing factor hormone receptor...
#
#                                               moa_image
# 0                                nitric oxide stimulant
# 1                                         HCV inhibitor
# 2                                free radical scavenger
# 3                       thromboxane receptor antagonist
# 4        SRC inhibitor|tubulin polymerization inhibitor
# ...                                                 ...
# 3471  intermediate conductance potassium channel blo...
# 3472  microsomal trigylceride transfer protein inhib...
# 3473  3beta-hydroxy-delta5-steroid dehydrogenase inh...
# 3476  gonadotropin releasing factor hormone receptor...
# 3477  gonadotropin releasing factor hormone receptor...
#
# [1402 rows x 7 columns]

# %%
all_metadata = all_metadata.drop_duplicates(subset=["pert_id"])
# Out:
#             pert_id          cmap_name  \
# 0     BRD-A12237696       L-citrulline
# 1     BRD-K05674516           PSI-7976
# 2     BRD-K26341917    L-ergothioneine
# 3     BRD-K29133151      BRD-K29133151
# 4     BRD-K29968218            KX-2391
# ...             ...                ...
# 3471  BRD-K21295289          senicapoc
# 3472  BRD-K92213669         lomitapide
# 3473  BRD-A66155091         trilostane
# 3476  BRD-K99504665  goserelin-acetate
# 3477  BRD-K62685538        triptorelin
#
#                                                     moa  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3471  Intermediate conductance potassium channel blo...
# 3472  Microsomal trigylceride transfer protein inhib...
# 3473  3beta-hydroxy-delta5-steroid dehydrogenase inh...
# 3476  Gonadotropin releasing factor hormone receptor...
# 3477  Gonadotropin releasing factor hormone receptor...
#
#                                        canonical_smiles  \
# 0                                  NC(CCCNC(N)=O)C(O)=O
# 1     CC(C)OC(=O)[C@H](C)N[P@@](=O)(OC[C@H]1O[C@@H](...
# 2           C[N+](C)(C)[C@@H](Cc1c[nH]c(=S)[nH]1)C(O)=O
# 3     OC(=O)CCCC=C/C[C@@H]1CO[C@@H](O[C@@H]1c1ccccc1...
# 4      O=C(Cc1ccc(cn1)-c1ccc(OCCN2CCOCC2)cc1)NCc1ccccc1
# ...                                                 ...
# 3471          NC(=O)C(c1ccccc1)(c1ccc(F)cc1)c1ccc(F)cc1
# 3472  FC(F)(F)CNC(=O)C1(CCCCN2CCC(CC2)NC(=O)c2ccccc2...
# 3473  C[C@]12CC[C@@H]3[C@@H](CC[C@@]45O[C@@H]4C(=O)C...
# 3476  CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...
# 3477  CC(C)C[C@H](NC(=O)[C@@H](Cc1c[nH]c2ccccc12)NC(...
#
#                         inchi_key  \
# 0     RHGKLRLOHDJJDR-UHFFFAOYSA-N
# 1     TTZHDVOVKQGIBA-YBSJRAAASA-N
# 2     SSISHJJTAXXQAX-ZETCQYMHSA-O
# 3     ZWAVGFSZMACJHA-PMNBYGLBSA-N
# 4     HUNGUWOZPQBXGX-UHFFFAOYSA-N
# ...                           ...
# 3471  SCTZUZTYRMOMKT-UHFFFAOYSA-N
# 3472  MBBCVAKAJPKAKM-UHFFFAOYSA-N
# 3473  RLQVKDVIBJCQGE-VWWPZJNLSA-N
# 3476  BLCLNMBMMGCOAS-URPVMXJPSA-N
# 3477  VXKHXGOKWPXYNA-PGBVPBMZSA-N
#
#                                               moa_l1000  \
# 0                                                   NaN
# 1                              RNA polymerase inhibitor
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3471  Intermediate conductance potassium channel blo...
# 3472  Microsomal trigylceride transfer protein inhib...
# 3473  3beta-hydroxy-delta5-steroid dehydrogenase inh...
# 3476  Gonadotropin releasing factor hormone receptor...
# 3477  Gonadotropin releasing factor hormone receptor...
#
#                                               moa_image
# 0                                nitric oxide stimulant
# 1                                         HCV inhibitor
# 2                                free radical scavenger
# 3                       thromboxane receptor antagonist
# 4        SRC inhibitor|tubulin polymerization inhibitor
# ...                                                 ...
# 3471  intermediate conductance potassium channel blo...
# 3472  microsomal trigylceride transfer protein inhib...
# 3473  3beta-hydroxy-delta5-steroid dehydrogenase inh...
# 3476  gonadotropin releasing factor hormone receptor...
# 3477  gonadotropin releasing factor hormone receptor...
#
# [1402 rows x 7 columns]

# %%
all_metadata.to_csv("compound_metadata.txt",sep="\t",index=None)

# %% [markdown]
# Now for every row, we want a final set of MoA labels

# %%
# function
def clean_moa(row,meta_moa,lincs_moa,image_moa):
    # split by "|"
    split_moas = []
    for moa in [meta_moa,lincs_moa,image_moa]:
        try:
            moa_list = moa.split("|")
        except:
            continue
        split_moas.append(moa_list)
    
    # flatten list
    moas_flat = [item for sublist in split_moas for item in sublist]
    
    # get unique moas
    if len(moas_flat)>0: # don't perform if no moas
        moas_lower = [moa.lower() for moa in moas_flat]
        moas_unique = list(set(moas_lower))
        moas_col = '|'.join(str(e) for e in moas_unique)
        
    # add back to row
    cleaned_row = row
    cleaned_row['moa_cleaned'] = moas_col

    # return row with added, cleaned moa col
    return(cleaned_row)

# %%
# apply the function
cleaned_metadata = all_metadata.apply(lambda row: clean_moa(row,row['moa'], row['moa_l1000'],row['moa_image']), axis=1)
cleaned_metadata
# Out:
#             pert_id          cmap_name  \
# 0     BRD-A12237696       L-citrulline
# 1     BRD-K05674516           PSI-7976
# 2     BRD-K26341917    L-ergothioneine
# 3     BRD-K29133151      BRD-K29133151
# 4     BRD-K29968218            KX-2391
# ...             ...                ...
# 3471  BRD-K21295289          senicapoc
# 3472  BRD-K92213669         lomitapide
# 3473  BRD-A66155091         trilostane
# 3476  BRD-K99504665  goserelin-acetate
# 3477  BRD-K62685538        triptorelin
#
#                                                     moa  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3471  Intermediate conductance potassium channel blo...
# 3472  Microsomal trigylceride transfer protein inhib...
# 3473  3beta-hydroxy-delta5-steroid dehydrogenase inh...
# 3476  Gonadotropin releasing factor hormone receptor...
# 3477  Gonadotropin releasing factor hormone receptor...
#
#                                        canonical_smiles  \
# 0                                  NC(CCCNC(N)=O)C(O)=O
# 1     CC(C)OC(=O)[C@H](C)N[P@@](=O)(OC[C@H]1O[C@@H](...
# 2           C[N+](C)(C)[C@@H](Cc1c[nH]c(=S)[nH]1)C(O)=O
# 3     OC(=O)CCCC=C/C[C@@H]1CO[C@@H](O[C@@H]1c1ccccc1...
# 4      O=C(Cc1ccc(cn1)-c1ccc(OCCN2CCOCC2)cc1)NCc1ccccc1
# ...                                                 ...
# 3471          NC(=O)C(c1ccccc1)(c1ccc(F)cc1)c1ccc(F)cc1
# 3472  FC(F)(F)CNC(=O)C1(CCCCN2CCC(CC2)NC(=O)c2ccccc2...
# 3473  C[C@]12CC[C@@H]3[C@@H](CC[C@@]45O[C@@H]4C(=O)C...
# 3476  CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...
# 3477  CC(C)C[C@H](NC(=O)[C@@H](Cc1c[nH]c2ccccc12)NC(...
#
#                         inchi_key  \
# 0     RHGKLRLOHDJJDR-UHFFFAOYSA-N
# 1     TTZHDVOVKQGIBA-YBSJRAAASA-N
# 2     SSISHJJTAXXQAX-ZETCQYMHSA-O
# 3     ZWAVGFSZMACJHA-PMNBYGLBSA-N
# 4     HUNGUWOZPQBXGX-UHFFFAOYSA-N
# ...                           ...
# 3471  SCTZUZTYRMOMKT-UHFFFAOYSA-N
# 3472  MBBCVAKAJPKAKM-UHFFFAOYSA-N
# 3473  RLQVKDVIBJCQGE-VWWPZJNLSA-N
# 3476  BLCLNMBMMGCOAS-URPVMXJPSA-N
# 3477  VXKHXGOKWPXYNA-PGBVPBMZSA-N
#
#                                               moa_l1000  \
# 0                                                   NaN
# 1                              RNA polymerase inhibitor
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3471  Intermediate conductance potassium channel blo...
# 3472  Microsomal trigylceride transfer protein inhib...
# 3473  3beta-hydroxy-delta5-steroid dehydrogenase inh...
# 3476  Gonadotropin releasing factor hormone receptor...
# 3477  Gonadotropin releasing factor hormone receptor...
#
#                                               moa_image  \
# 0                                nitric oxide stimulant
# 1                                         HCV inhibitor
# 2                                free radical scavenger
# 3                       thromboxane receptor antagonist
# 4        SRC inhibitor|tubulin polymerization inhibitor
# ...                                                 ...
# 3471  intermediate conductance potassium channel blo...
# 3472  microsomal trigylceride transfer protein inhib...
# 3473  3beta-hydroxy-delta5-steroid dehydrogenase inh...
# 3476  gonadotropin releasing factor hormone receptor...
# 3477  gonadotropin releasing factor hormone receptor...
#
#                                             moa_cleaned
# 0                                nitric oxide stimulant
# 1                hcv inhibitor|rna polymerase inhibitor
# 2                                free radical scavenger
# 3                       thromboxane receptor antagonist
# 4        src inhibitor|tubulin polymerization inhibitor
# ...                                                 ...
# 3471  intermediate conductance potassium channel blo...
# 3472  microsomal trigylceride transfer protein inhib...
# 3473  3beta-hydroxy-delta5-steroid dehydrogenase inh...
# 3476  gonadotropin releasing factor hormone receptor...
# 3477  gonadotropin releasing factor hormone receptor...
#
# [1402 rows x 8 columns]

# %%
# save metadata file
cleaned_metadata.to_csv("cleaned_metadata.txt",sep="\t",index=None)
